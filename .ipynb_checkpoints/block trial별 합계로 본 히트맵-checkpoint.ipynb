# %%
import pandas as pd
from datetime import datetime

data = pd.read_excel('./clean_dataset/clean_stimulus/session_5_clean_stimulus_new.xlsx') # stimulus 시점 표시된 clean data 가져오기.
data = data.drop('Unnamed: 0', axis = 1)
data.head()
# Out:
#                  TimeStamp  Delta_AF8  Theta_AF8  Alpha_AF8  Beta_AF8  \
# 0  2022-07-22 16:47:05.270   0.653585   0.779724   0.756711  0.682772
# 1  2022-07-22 16:47:05.271   0.653585   0.779724   0.756711  0.682772
# 2  2022-07-22 16:47:05.271   0.653585   0.779724   0.756711  0.682772
# 3  2022-07-22 16:47:05.271   0.653585   0.779724   0.756711  0.682772
# 4  2022-07-22 16:47:05.272   0.653585   0.779724   0.756711  0.682772
#
#    Gamma_AF8  stimulus  beta/theta temp
# 0   0.091385         0    0.875659    0
# 1   0.091385         0    0.875659    0
# 2   0.091385         0    0.875659    0
# 3   0.091385         0    0.875659    0
# 4   0.091385         0    0.875659    0

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df_after= data[data['temp'] == '6after'][['Beta_AF8']].copy()

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_after.transpose(), cmap='Blues', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
import pandas as pd
from datetime import datetime

data = pd.read_excel('./clean_dataset/clean_stimulus/session_5_clean_stimulus.xlsx') # stimulus 시점 표시된 clean data 가져오기.
data = data.drop('Unnamed: 0', axis = 1)
data.head()
# Out:
#                  TimeStamp  Delta_AF8  Theta_AF8  Alpha_AF8  Beta_AF8  \
# 0  2022-07-22 16:47:05.270   0.653585   0.779724   0.756711  0.682772
# 1  2022-07-22 16:47:05.271   0.653585   0.779724   0.756711  0.682772
# 2  2022-07-22 16:47:05.271   0.653585   0.779724   0.756711  0.682772
# 3  2022-07-22 16:47:05.271   0.653585   0.779724   0.756711  0.682772
# 4  2022-07-22 16:47:05.272   0.653585   0.779724   0.756711  0.682772
#
#    Gamma_AF8  stimulus temp
# 0   0.091385         0    0
# 1   0.091385         0    0
# 2   0.091385         0    0
# 3   0.091385         0    0
# 4   0.091385         0    0

# %% [markdown]
# # after로 본거

# %%
df_1=data[data['temp'] == '1after'][:244][['Beta_AF8']].copy()
df_2=data[data['temp'] == '6after'][:244][['Beta_AF8']].copy()
df_3=data[data['temp'] == '11after'][:244][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial1=df_1+df_2+df_3 #244
df_trial1
# Out:
#      Beta_AF8
# 0    1.786796
# 1    1.786796
# 2    1.786796
# 3    1.773060
# 4    1.773060
# ..        ...
# 239  1.848001
# 240  1.848001
# 241  1.848001
# 242  1.848001
# 243  1.848001
#
# [244 rows x 1 columns]

# %%
df_1=data[data['temp'] == '2after'][:244][['Beta_AF8']].copy()
df_2=data[data['temp'] == '7after'][:244][['Beta_AF8']].copy()
df_3=data[data['temp'] == '12after'][:244][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial2=df_1+df_2+df_3
df_trial2
# Out:
#      Beta_AF8
# 0    1.758885
# 1    1.758885
# 2    1.758885
# 3    1.732604
# 4    1.732604
# ..        ...
# 239  1.972784
# 240  1.972784
# 241  1.972784
# 242  1.972784
# 243  1.972784
#
# [244 rows x 1 columns]

# %%
df_1=data[data['temp'] == '3after'][:244][['Beta_AF8']].copy()
df_2=data[data['temp'] == '8after'][:244][['Beta_AF8']].copy()
df_3=data[data['temp'] == '13after'][:244][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial3=df_1+df_2+df_3
df_trial3
# Out:
#      Beta_AF8
# 0    2.417141
# 1    2.417141
# 2    2.417141
# 3    2.417141
# 4    2.417141
# ..        ...
# 239  2.308026
# 240  2.308026
# 241  2.308026
# 242  2.308026
# 243  2.308026
#
# [244 rows x 1 columns]

# %%
df_1=data[data['temp'] == '4after'][:244][['Beta_AF8']].copy()
df_2=data[data['temp'] == '9after'][:244][['Beta_AF8']].copy()
df_3=data[data['temp'] == '14after'][:244][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial4=df_1+df_2+df_3
df_trial4
# Out:
#      Beta_AF8
# 0    2.187028
# 1    2.187028
# 2    2.187028
# 3    2.187028
# 4    2.187028
# ..        ...
# 239  2.291953
# 240  2.291953
# 241  2.291953
# 242  2.291953
# 243  2.291953
#
# [244 rows x 1 columns]

# %%
df_1=data[data['temp'] == '5after'][:244][['Beta_AF8']].copy()
df_2=data[data['temp'] == '10after'][:244][['Beta_AF8']].copy()
df_3=data[data['temp'] == '15after'][:244][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial5=df_1+df_2+df_3
df_trial5
# Out:
#      Beta_AF8
# 0    1.892236
# 1    1.892236
# 2    1.892236
# 3    1.892236
# 4    1.892236
# ..        ...
# 239  1.871638
# 240  1.871638
# 241  1.871638
# 242  1.871638
# 243  1.871638
#
# [244 rows x 1 columns]

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial1.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial2.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial3.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial4.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial5.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %% [markdown]
# # ref로 본것

# %%
df_1=data[data['temp'] == '1ref'][:241][['Beta_AF8']].copy()
df_2=data[data['temp'] == '6ref'][:241][['Beta_AF8']].copy()
df_3=data[data['temp'] == '11ref'][:241][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial1_ref=df_1+df_2+df_3
df_trial1_ref
# Out:
#      Beta_AF8
# 0    2.161245
# 1    2.161245
# 2    2.161245
# 3    2.161245
# 4    2.161245
# ..        ...
# 236  2.423228
# 237  2.423228
# 238  2.423228
# 239  2.423228
# 240  2.423228
#
# [241 rows x 1 columns]

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial1_ref.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
df_1=data[data['temp'] == '2ref'][:241][['Beta_AF8']].copy()
df_2=data[data['temp'] == '7ref'][:241][['Beta_AF8']].copy()
df_3=data[data['temp'] == '12ref'][:241][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial2_ref=df_1+df_2+df_3
df_trial2_ref
# Out:
#      Beta_AF8
# 0    1.770798
# 1    1.770798
# 2    1.770798
# 3    1.770798
# 4    1.770798
# ..        ...
# 236  1.961586
# 237  1.961586
# 238  1.961586
# 239  1.969175
# 240  1.969175
#
# [241 rows x 1 columns]

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial2_ref.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
df_1=data[data['temp'] == '3ref'][:241][['Beta_AF8']].copy()
df_2=data[data['temp'] == '8ref'][:241][['Beta_AF8']].copy()
df_3=data[data['temp'] == '13ref'][:241][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial3_ref=df_1+df_2+df_3
df_trial3_ref
# Out:
#      Beta_AF8
# 0    1.986146
# 1    1.986146
# 2    1.986146
# 3    1.986146
# 4    1.986146
# ..        ...
# 236  1.928859
# 237  1.928859
# 238  1.928859
# 239  1.966721
# 240  1.966721
#
# [241 rows x 1 columns]

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial3_ref.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
df_1=data[data['temp'] == '4ref'][:241][['Beta_AF8']].copy()
df_2=data[data['temp'] == '9ref'][:241][['Beta_AF8']].copy()
df_3=data[data['temp'] == '14ref'][:241][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial4_ref=df_1+df_2+df_3
df_trial4_ref
# Out:
#      Beta_AF8
# 0    1.907080
# 1    1.907080
# 2    1.907080
# 3    1.907080
# 4    1.907080
# ..        ...
# 236  1.867861
# 237  1.867861
# 238  1.867861
# 239  1.867861
# 240  1.867861
#
# [241 rows x 1 columns]

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial4_ref.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()

# %%
df_1=data[data['temp'] == '5ref'][:241][['Beta_AF8']].copy()
df_2=data[data['temp'] == '10ref'][:241][['Beta_AF8']].copy()
df_3=data[data['temp'] == '15ref'][:241][['Beta_AF8']].copy()
df_1.reset_index(drop=True,inplace=True)
df_2.reset_index(drop=True,inplace=True)
df_3.reset_index(drop=True,inplace=True)

df_trial5_ref=df_1+df_2+df_3
df_trial5_ref
# Out:
#      Beta_AF8
# 0    2.210623
# 1    2.210623
# 2    2.210623
# 3    2.210623
# 4    2.210623
# ..        ...
# 236  2.312308
# 237  2.312308
# 238  2.312308
# 239  2.312308
# 240  2.312308
#
# [241 rows x 1 columns]

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(50,4)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(df_trial5_ref.transpose(), cmap='Reds', annot=False)
plt.xlabel("Time")

sfig = ax.get_figure()
