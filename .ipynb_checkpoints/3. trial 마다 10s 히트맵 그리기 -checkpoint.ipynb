# %% [markdown]
# # trial 마다 10s 히트맵 그리기

# %%
import pandas as pd
from datetime import datetime

data = pd.read_excel('./clean_dataset/session_3_clean.xlsx') # stimulus 시점 표시된 clean data 가져오기.
data
# Out:
#        Unnamed: 0                TimeStamp  Delta_AF8  Theta_AF8  Alpha_AF8  \
# 0               0  2022-07-17 23:59:20.523   0.227267   0.699052   0.294166
# 1               1  2022-07-17 23:59:20.524   0.227267   0.699052   0.294166
# 2               2  2022-07-17 23:59:20.524   0.227267   0.699052   0.294166
# 3               3  2022-07-17 23:59:20.525   0.227267   0.699052   0.294166
# 4               4  2022-07-17 23:59:20.525   0.227267   0.699052   0.294166
# ...           ...                      ...        ...        ...        ...
# 66235       66276  2022-07-18 00:03:39.157   0.593957  -0.029203   0.202880
# 66236       66277  2022-07-18 00:03:39.157   0.593957  -0.029203   0.202880
# 66237       66278  2022-07-18 00:03:39.158   0.593957  -0.029203   0.202880
# 66238       66279  2022-07-18 00:03:39.158   0.593957  -0.029203   0.202880
# 66239       66280  2022-07-18 00:03:39.158   0.593957  -0.029203   0.202880
#
#        Beta_AF8  Gamma_AF8  stimulus
# 0      0.706565   0.369843         0
# 1      0.706565   0.369843         0
# 2      0.706565   0.369843         0
# 3      0.706565   0.369843         0
# 4      0.706565   0.369843         0
# ...         ...        ...       ...
# 66235  0.268543  -0.067624         0
# 66236  0.268543  -0.067624         0
# 66237  0.268543  -0.067624         0
# 66238  0.268543  -0.067624         0
# 66239  0.268543  -0.067624         0
#
# [66240 rows x 8 columns]

# %%
data = data.drop('Unnamed: 0', axis = 1)
data.head()
# Out:
#                  TimeStamp  Delta_AF8  Theta_AF8  Alpha_AF8  Beta_AF8  \
# 0  2022-07-17 23:59:20.523   0.227267   0.699052   0.294166  0.706565
# 1  2022-07-17 23:59:20.524   0.227267   0.699052   0.294166  0.706565
# 2  2022-07-17 23:59:20.524   0.227267   0.699052   0.294166  0.706565
# 3  2022-07-17 23:59:20.525   0.227267   0.699052   0.294166  0.706565
# 4  2022-07-17 23:59:20.525   0.227267   0.699052   0.294166  0.706565
#
#    Gamma_AF8  stimulus
# 0   0.369843         0
# 1   0.369843         0
# 2   0.369843         0
# 3   0.369843         0
# 4   0.369843         0

# %%
# 자극 시점 index 저장 (맨앞, 맨뒤 인덱스 포함)
point = []
point.append(0)
for i in range(len(data)) :
    if data['stimulus'][i] == 1:
        point.append(i)
point.append(len(data))
point
# Out:
# [0,
#  6960,
#  9780,
#  12600,
#  15408,
#  18228,
#  28716,
#  31536,
#  34352,
#  37176,
#  39984,
#  50484,
#  53292,
#  56114,
#  58932,
#  61752,
#  66240]

# %%
start_idx = point[1]
end_idx = point[2]
data_h = data[start_idx:end_idx]
data_h = data_h.drop('stimulus', axis = 1)
data_h = data_h.drop('TimeStamp', axis = 1)
# Out:
#   File "<ipython-input-18-be77c70af986>", line 4
#     data_h = data_h.drop('stimulus','Timestamp' axis = 1)
#                                                 ^
# SyntaxError: invalid syntax

# %%
data_h_T = data_h.transpose()

# %%
data_h_T
# Out:
#                6960      6961      6962      6963      6964      6965  \
# Delta_AF8 -0.387009 -0.387009 -0.387009 -0.387009 -0.387009 -0.387009
# Theta_AF8  0.401710  0.401710  0.401710  0.401710  0.401710  0.401710
# Alpha_AF8  0.063209  0.063209  0.063209  0.063209  0.063209  0.063209
# Beta_AF8   0.521645  0.521645  0.521645  0.521645  0.521645  0.521645
# Gamma_AF8  0.056930  0.056930  0.056930  0.056930  0.056930  0.056930
#
#                6966      6967      6968      6969  ...      9770      9771  \
# Delta_AF8 -0.387009 -0.387009 -0.387009 -0.387009  ...  0.871533  0.871533
# Theta_AF8  0.401710  0.401710  0.401710  0.401710  ...  0.397353  0.397353
# Alpha_AF8  0.063209  0.063209  0.063209  0.063209  ...  0.094797  0.094797
# Beta_AF8   0.521645  0.521645  0.521645  0.521645  ...  0.370860  0.370860
# Gamma_AF8  0.056930  0.056930  0.056930  0.056930  ...  0.230593  0.230593
#
#                9772      9773      9774      9775      9776      9777  \
# Delta_AF8  0.871533  0.871533  0.871533  0.871533  0.871533  0.871533
# Theta_AF8  0.397353  0.397353  0.397353  0.397353  0.397353  0.397353
# Alpha_AF8  0.094797  0.094797  0.094797  0.094797  0.094797  0.094797
# Beta_AF8   0.370860  0.370860  0.370860  0.370860  0.370860  0.370860
# Gamma_AF8  0.230593  0.230593  0.230593  0.230593  0.230593  0.230593
#
#                9778      9779
# Delta_AF8  0.871533  0.871533
# Theta_AF8  0.397353  0.397353
# Alpha_AF8  0.094797  0.094797
# Beta_AF8   0.370860  0.370860
# Gamma_AF8  0.230593  0.230593
#
# [5 rows x 2820 columns]

# %%
from pandas import Series, DataFrame


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# xtime = [0,' ',' ',' ',' ',' ',' ',' ',' ',' ',' ', ' ',0.5,' ',' ',' ',' ',' ',' ',' ',' ',' ',' ',' ',1]

sns.set(rc = {'figure.figsize':(35,3)})
# ax=sns.heatmap(data_h_T, cmap='Reds', annot=True,xticklabels=xtime)
ax=sns.heatmap(data_h_T, cmap='Reds', annot=False)
plt.xlabel("Time")
# Out:
# Text(0.5, 3.5, 'Time')
